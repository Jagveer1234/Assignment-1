# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagveer1234/Assignment-1/blob/main/Credit_risk_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dt=pd.read_csv("/content/loan_data.csv")

# %%
dt.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1000000    7423388       5583         5583             5530   60 months
# 1  1000001    7550634      12889        12889            12818   60 months
# 2  1000002    5304572      28413        28413            28365   60 months
# 3  1000003    3234489      13275        13275            13177   36 months
# 4  1000004    8204212       3461         3461             3451   36 months
#
#    int_rate  installment grade sub_grade  ... total_bal_il il_util  \
# 0      9.02       177.59     C        F5  ...        73260    38.5
# 1     21.10       486.26     E        F5  ...        61649    89.6
# 2     22.00      1085.11     F        G2  ...        67743    14.2
# 3     10.78       433.22     C        A1  ...        13596    35.8
# 4     24.05       135.88     C        C3  ...        32746    69.8
#
#   open_rv_12m  open_rv_24m max_bal_bc all_util total_rev_hi_lim inq_fi  \
# ...

# %%
loan_backup=pd.read_csv("/content/loan_data.csv")

# %%
dt
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0     1000000    7423388       5583         5583             5530   60 months
# 1     1000001    7550634      12889        12889            12818   60 months
# 2     1000002    5304572      28413        28413            28365   60 months
# 3     1000003    3234489      13275        13275            13177   36 months
# 4     1000004    8204212       3461         3461             3451   36 months
# ...       ...        ...        ...          ...              ...         ...
# 1995  1001995    7154512      10783        10783            10709   36 months
# 1996  1001996    4759505      14233        14233            14232   60 months
# 1997  1001997    9415414      25484        25484            25471   36 months
# 1998  1001998    6418952      26068        26068            26039   60 months
# 1999  1001999    5609688       1191         1191             1143   60 months
#
# ...

# %%
pd.options.display.max_columns=None

# %%
dt.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1000000    7423388       5583         5583             5530   60 months
# 1  1000001    7550634      12889        12889            12818   60 months
# 2  1000002    5304572      28413        28413            28365   60 months
# 3  1000003    3234489      13275        13275            13177   36 months
# 4  1000004    8204212       3461         3461             3451   36 months
#
#    int_rate  installment grade sub_grade  emp_title emp_length home_ownership  \
# 0      9.02       177.59     C        F5    Analyst    7 years            OWN
# 1     21.10       486.26     E        F5    Analyst  10+ years           RENT
# 2     22.00      1085.11     F        G2     Doctor    7 years            OWN
# 3     10.78       433.22     C        A1  Developer    2 years            OWN
# 4     24.05       135.88     C        C3     Doctor    6 years            OWN
#
# ...

# %%
dt.columns.values
# Out:
# array(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti',
#        'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d',
#        'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           2000 non-null   int64
#  1   member_id                    2000 non-null   int64
#  2   loan_amnt                    2000 non-null   int64
#  3   funded_amnt                  2000 non-null   int64
#  4   funded_amnt_inv              2000 non-null   int64
#  5   term                         2000 non-null   object
#  6   int_rate                     2000 non-null   float64
#  7   installment                  2000 non-null   float64
#  8   grade                        2000 non-null   object
#  9   sub_grade                    2000 non-null   object
#  10  emp_title                    1800 non-null   object
#  11  emp_length                   2000 non-null   object
#  12  home_ownership               2000 non-null   object
# ...

# %%
dt['emp_length'].unique()
# Out:
# array(['7 years', '10+ years', '2 years', '6 years', '1 year', '8 years',
#        '4 years', '5 years', '< 1 year', '9 years', '3 years'],
#       dtype=object)

# %%
dt['emp_length_int']=dt['emp_length'].str.replace('+ years','')
dt['emp_length_int']=dt['emp_length'].str.replace('< 1 year',str(0))
dt['emp_length_int']=dt['emp_length'].str.replace(' years','')

# %%
type(dt['emp_length_int'][0])
# Out:
# str

# %%
dt['emp_length_int']=pd.to_numeric(dt['emp_length_int'],errors='coerce')

# %%
type(dt['emp_length_int'][0])
# Out:
# numpy.float64
